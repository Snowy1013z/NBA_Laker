# %% [markdown]
# <a href="https://colab.research.google.com/github/Snowy1013z/NBA_Laker/blob/main/NBA%20and%20Star%20Players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import os, numpy pandas, google  drive an change directory

import os
import numpy as np
import pandas as pd

from google.colab import drive

import seaborn as sns
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm

# %%
pd.set_option('display.max_columns', None)


import warnings
warnings.filterwarnings('ignore')

# %%
drive.mount('/content/drive')

# Set Working Directory #
os.chdir("/content/drive/MyDrive/Spring2025/#2_574/combined file with game ID")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_1314= pd.read_csv('2013-2014_NBA_PbP_Logs.csv')
data_1415= pd.read_csv('2014-2015_NBA_PbP_Logs.csv')
data_1516= pd.read_csv('2015-2016_NBA_PbP_Logs.csv')
data_1617= pd.read_csv('2016-2017_NBA_PbP_Logs.csv')
data_1718= pd.read_csv('2017-2018_NBA_PbP_Logs.csv')
data_1819= pd.read_csv('2018-2019_NBA_PbP_Logs.csv')
data_1920= pd.read_csv('2019-2020_NBA_PbP_Logs.csv')
data_2021= pd.read_csv('2020-2021_NBA_PbP_Logs.csv')
data_2122= pd.read_csv('2021-2022_NBA_PbP_Logs.csv')
data_2223= pd.read_csv('2022-2023_NBA_PbP_Logs.csv')
data_2324= pd.read_csv('2023-2024_NBA_PbP_Logs.csv')

# %% [markdown]
# # 2012-2019 - New Orleans Pelicans (NOP)
# # 2019-Present - Los Angeles Lakers (LAL)

# %%
data_1314.head()
# Out:
#     game_id                data_set        date             a1           a2  \
# 0  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 1  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 2  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 3  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 4  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
#
#             a3               a4              a5              h1           h2  \
# 0  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 1  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 2  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 3  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 4  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
#
# ...

# %%
data_1314[data_1314['matchup'].str.contains('NOP')]
# Out:
#          game_id                data_set        date              a1  \
# 465     21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 466     21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 467     21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 468     21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 469     21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# ...          ...                     ...         ...             ...
# 583999  21300286  2013-14 Regular Season  2013-12-06     Jeremy Lamb
# 584000  21300286  2013-14 Regular Season  2013-12-06     Jeremy Lamb
# 584001  21300286  2013-14 Regular Season  2013-12-06     Jeremy Lamb
# 584002  21300286  2013-14 Regular Season  2013-12-06     Jeremy Lamb
# 584003  21300286  2013-14 Regular Season  2013-12-06     Jeremy Lamb
#
#                       a2            a3               a4  \
# 465     Brandon Jennings    Josh Smith      Greg Monroe
# ...

# %%
# List of players from the New Orleans Pelicans (NOP) for the specified seasons

nop_players_2013_2014 = [
    "Anthony Davis", "Tyreke Evans", "Jrue Holiday", "Ryan Anderson", "Eric Gordon",
    "Omer Asik", "Alexis Ajinca", "Austin Rivers", "Luke Babbitt", "Darius Miller",
    "Al-Farouq Aminu", "Greg Stiemsma", "John Salmons", "Shawne Williams", "Pierre Jackson"
]

nop_players_2015_2016 = [
    "Anthony Davis", "Tyreke Evans", "Jrue Holiday", "Ryan Anderson", "Eric Gordon",
    "Omer Asik", "Alexis Ajinca", "Austin Rivers", "Luke Babbitt", "Darius Miller",
    "Al-Farouq Aminu", "Greg Stiemsma", "John Salmons", "Shawne Williams", "Pierre Jackson"
]

nop_players_2016_2017 = [
    "Anthony Davis", "Jrue Holiday", "DeMarcus Cousins", "E'Twaun Moore", "Solomon Hill",
    "Alexis Ajinca", "Cheick Diallo", "Langston Galloway", "Jameer Nelson", "Terrence Jones",
    "Dante Cunningham", "Quincy Pondexter", "Tony Allen", "Jordan Crawford", "Dairis Bertans", "Tim Frazier"
]

nop_players_2017_2018 = [
    "Anthony Davis", "Jrue Holiday", "Nikola Mirotic", "DeMarcus Cousins", "E'Twaun Moore",
    "Solomon Hill", "Alexis Ajinca", "Cheick Diallo", "Ian Clark", "Nikola Mirotic",
    "Darius Miller", "Jahlil Okafor", "Jrue Holiday", "Frank Jackson", "Emeka Okafor",
    "Dante Cunningham", "Jameer Nelson", "Tim Frazier"
]

nop_players_2018_2019 = [
    "Anthony Davis", "Jrue Holiday", "Nikola Mirotic", "E'Twaun Moore", "Solomon Hill",
    "Alexis Ajinca", "Cheick Diallo", "Ian Clark", "Darius Miller", "Jahlil Okafor",
    "Frank Jackson", "Emeka Okafor", "Dante Cunningham", "Jameer Nelson", "Tim Frazier"
]

# Display the lists
#nop_players_2013_2014, nop_players_2015_2016, nop_players_2016_2017, nop_players_2017_2018, nop_players_2018_2019

# %%
# prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played
nop_games_1314 = data_1314[data_1314['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1314 = 0
for player in nop_players_2013_2014:
  player_points = data_1314[data_1314['player'] == player]['points'].sum()
  total_points1314 += player_points

print(f"Total points for NOP players in the 2013-2014 season: {total_points1314}")
# Out:
# Total points for NOP players in the 2013-2014 season: 7240.0

# %%
nop_players_2014_2015 = [
    "Anthony Davis",
    "Tyreke Evans",
    "Jrue Holiday",
    "Ryan Anderson",
    "Eric Gordon",
    "Omer Asik",
    "Alexis Ajinca",
    "Austin Rivers",
    "Luke Babbitt",
    "Darius Miller",
    "Al-Farouq Aminu",
    "Greg Stiemsma",
    "John Salmons",
    "Shawne Williams",
    "Pierre Jackson",
]

# prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played
nop_games_1415 = data_1415[data_1415['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1415 = 0
for player in nop_players_2014_2015:
  player_points = nop_games_1415[nop_games_1415['player'] == player]['points'].sum()
  total_points1415 += player_points

print(f"Total points for NOP players in the 2014-2015 season: {total_points1415}")
# Out:
# Total points for NOP players in the 2014-2015 season: 7092.0

# %%
# prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played
nop_games_1516 = data_1516[data_1516['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1516 = 0
for player in nop_players_2015_2016:
  player_points = nop_games_1516[nop_games_1516['player'] == player]['points'].sum()
  total_points1516 += player_points

print(f"Total points for NOP players in the 2015-2016 season: {total_points1516}")
# Out:
# Total points for NOP players in the 2015-2016 season: 5788.0

# %%
# prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played
nop_games_1617 = data_1617[data_1617['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1617 = 0
for player in nop_players_2016_2017:
  player_points = nop_games_1617[nop_games_1617['player'] == player]['points'].sum()
  total_points1617 += player_points

print(f"Total points for NOP players in the 2016-2017 season: {total_points1617}")
# Out:
# Total points for NOP players in the 2016-2017 season: 7415.0

# %%
#prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played
nop_games_1718 = data_1718[data_1718['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1718 = 0
for player in nop_players_2017_2018:
  player_points = nop_games_1718[nop_games_1718['player'] == player]['points'].sum()
  total_points1718 += player_points

print(f"Total points for NOP players in the 2017-2018 season: {total_points1718}")
# Out:
# Total points for NOP players in the 2017-2018 season: 11628.0

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1819 = data_1819[data_1819['matchup'].str.contains('NOP')]

# Calculate total points for Celtics players
total_points1819 = 0
for player in nop_players_2018_2019:
  player_points = nop_games_1819[nop_games_1819['player'] == player]['points'].sum()
  total_points1819 += player_points

print(f"Total points for NOP players in the 2018-2019 season: {total_points1819}")
# Out:
# Total points for NOP players in the 2018-2019 season: 6853.0

# %%
# prompt: create a line chart show total score through seasons use seaborn

# Create a dictionary to store the total points for each season
total_points_by_season = {
    "2013-2014": total_points1314,
    "2014-2015": total_points1415,
    "2015-2016": total_points1516,
    "2016-2017": total_points1617,
    "2017-2018": total_points1718,
    "2018-2019": total_points1819
}

# Create a DataFrame from the dictionary
seasons_df = pd.DataFrame.from_dict(total_points_by_season, orient='index', columns=['Total Points'])

# Reset the index to make the season a column
seasons_df = seasons_df.reset_index().rename(columns={'index': 'Season'})

# Create the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(x='Season', y='Total Points', data=seasons_df, marker='o')
plt.title('Total NOP Points per Season')
plt.xlabel('Season')
plt.ylabel('Total Points')
plt.xticks(rotation=45)
plt.show()

# %%
# Lists of Los Angeles Lakers players from 2018 to 2024 by season

#lal_players_2018_2019 = [
#    "LeBron James", "Lonzo Ball", "Brandon Ingram", "Kyle Kuzma", "Josh Hart",
#    "Rajon Rondo", "Lance Stephenson", "Michael Beasley", "JaVale McGee", "Tyson Chandler",
#    "Kentavious Caldwell-Pope", "Ivica Zubac", "Svi Mykhailiuk"

lal_players_2019_2020 = [
    "LeBron James", "Anthony Davis", "Dwight Howard", "Danny Green", "Kentavious Caldwell-Pope",
    "Kyle Kuzma", "Rajon Rondo", "Alex Caruso", "JaVale McGee", "Markieff Morris",
    "Jared Dudley", "Quinn Cook", "Talen Horton-Tucker"
]

lal_players_2020_2021 = [
    "LeBron James", "Anthony Davis", "Russell Westbrook", "Dwight Howard", "Kentavious Caldwell-Pope",
    "Kyle Kuzma", "Montrezl Harrell", "Marc Gasol", "Wesley Matthews", "Talen Horton-Tucker",
    "Alex Caruso", "Jared Dudley", "Kostas Antetokounmpo"
]

lal_players_2021_2022 = [
    "LeBron James", "Anthony Davis", "Russell Westbrook", "Dwight Howard", "Carmelo Anthony",
    "Malik Monk", "Austin Reaves", "Kendrick Nunn", "Stanley Johnson", "Wayne Ellington",
    "Rajon Rondo", "DeAndre Jordan"
]

lal_players_2022_2023 = [
    "LeBron James", "Anthony Davis", "D'Angelo Russell", "Rui Hachimura", "Austin Reaves",
    "Jared Vanderbilt", "Malik Beasley", "Dennis Schröder", "Lonnie Walker IV", "Wenyen Gabriel",
    "Thomas Bryant", "Troy Brown Jr.", "Russell Westbrook"
]

lal_players_2023_2024 = [
    "LeBron James", "Anthony Davis", "Luka Dončić", "Austin Reaves", "D'Angelo Russell",
    "Jared Vanderbilt", "Malik Beasley", "Rui Hachimura", "Dennis Schröder", "Troy Brown Jr.",
    "Wenyen Gabriel", "Max Christie", "Gabe Vincent", "Jaden Ivey"
]

#lal_players_2018_2019, lal_players_2019_2020, lal_players_2020_2021, lal_players_2021_2022, lal_players_2022_2023, lal_players_2023_2024

# %%
# Filter the dataframe for games where the Celtics played
lal_games_1920 = data_1920[data_1920['matchup'].str.contains('LAL')]

# Calculate total points for Celtics players
total_points1920 = 0
for player in lal_players_2019_2020:
  player_points = lal_games_1920[lal_games_1920['player'] == player]['points'].sum()
  total_points1920 += player_points

print(f"Total points for LAL players in the 2019-2020 season: {total_points1920}")
# Out:
# Total points for LAL players in the 2019-2020 season: 9683.0

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2021 = data_2021[data_2021['matchup'].str.contains('LAL')]

# Calculate total points for Celtics players
total_points2021 = 0
for player in lal_players_2020_2021:
  player_points = lal_games_2021[lal_games_2021['player'] == player]['points'].sum()
  total_points2021 += player_points

print(f"Total points for LAL players in the 2020-2021 season: {total_points2021}")
# Out:
# Total points for LAL players in the 2020-2021 season: 6466.0

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2122 = data_2122[data_2122['matchup'].str.contains('LAL')]

# Calculate total points for Celtics players
total_points2122 = 0
for player in lal_players_2021_2022:
  player_points = lal_games_2122[lal_games_2122['player'] == player]['points'].sum()
  total_points2122 += player_points

print(f"Total points for LAL players in the 2021-2022 season: {total_points2122}")
# Out:
# Total points for LAL players in the 2021-2022 season: 7649.0

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2223 = data_2223[data_2223['matchup'].str.contains('LAL')]

# Calculate total points for Celtics players
total_points2223 = 0
for player in lal_players_2022_2023:
  player_points = lal_games_2223[lal_games_2223['player'] == player]['points'].sum()
  total_points2223 += player_points

print(f"Total points for LAL players in the 2022-2023 season: {total_points2223}")
# Out:
# Total points for LAL players in the 2022-2023 season: 9371.0

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2324 = data_2324[data_2324['matchup'].str.contains('LAL')]

# Calculate total points for Celtics players
total_points2324 = 0
for player in lal_players_2023_2024:
  player_points = lal_games_2324[lal_games_2324['player'] == player]['points'].sum()
  total_points2324 += player_points

print(f"Total points for LAL players in the 2023-2024 season: {total_points2324}")
# Out:
# Total points for LAL players in the 2023-2024 season: 8366.0

# %%
# prompt: create a line chart show total score through seasons use seaborn

# Create a dictionary to store the total points for each season
total_points_by_season = {
    "2013-2014": total_points1314,
    "2014-2015": total_points1415,
    "2015-2016": total_points1516,
    "2016-2017": total_points1617,
    "2017-2018": total_points1718,
    "2018-2019": total_points1819,
    "2019-2020": total_points1920,
    "2020-2021": total_points2021,
    "2021-2022": total_points2122,
    "2022-2023": total_points2223,
    "2023-2024": total_points2324
}

# Create a DataFrame from the dictionary
seasons_df = pd.DataFrame.from_dict(total_points_by_season, orient='index', columns=['Total Points'])

# Reset the index to make the season a column
seasons_df = seasons_df.reset_index().rename(columns={'index': 'Season'})

# Create the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(x='Season', y='Total Points', data=seasons_df, marker='o')
plt.title('Total NOP & LAL Points per Season')
plt.xlabel('Season')
plt.ylabel('Total Points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The graph shows the total points scored by the Boston Celtics across various NBA seasons, from 2013-2014 to 2018-2019. The points progressively increase, with a peak in the 2016-2017 season, which is also considered the peak year of Isaiah Thomas' career, followed by a slight decline in the 2018-2019 season. The graph highlights the team's overall scoring performance over this period.

# %% [markdown]
# After prove that a star player join make an impact to the team.
#
# Now we analyze how his performance change depend on who he plays with.

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1314 = data_1314[data_1314['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1314_nop = nop_games_1314[nop_games_1314['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2013-2014 season: {davis_points1314_nop}")

nop_games_1314['On Court Players'] = nop_games_1314['a1'] + "_" +  nop_games_1314['a2'] + "_" +  nop_games_1314['a3'] + "_" +  nop_games_1314['a4'] + "_" +  nop_games_1314['a5'] + "_" + nop_games_1314['h1'] + "_" +  nop_games_1314['h2'] + "_" +  nop_games_1314['h3'] + "_" +  nop_games_1314['h4'] + "_" +  nop_games_1314['h5']

nop_games_1314['Davis on court'] = np.where(nop_games_1314['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1314['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2013-2014 season: 1394.0
# Davis on court
# On Court     21938
# Off Court    15232
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1415 = data_1415[data_1415['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1415_nop = nop_games_1415[nop_games_1415['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2014-2015 season: {davis_points1415_nop}")

nop_games_1415['On Court Players'] = nop_games_1415['a1'] + "_" +  nop_games_1415['a2'] + "_" +  nop_games_1415['a3'] + "_" +  nop_games_1415['a4'] + "_" +  nop_games_1415['a5'] + "_" + nop_games_1415['h1'] + "_" +  nop_games_1415['h2'] + "_" +  nop_games_1415['h3'] + "_" +  nop_games_1415['h4'] + "_" +  nop_games_1415['h5']

nop_games_1415['Davis on court'] = np.where(nop_games_1415['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1415['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2014-2015 season: 1782.0
# Davis on court
# On Court     24081
# Off Court    14007
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1516 = data_1516[data_1516['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1516_nop = nop_games_1516[nop_games_1516['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2015-2016 season: {davis_points1516_nop}")

nop_games_1516['On Court Players'] = nop_games_1516['a1'] + "_" +  nop_games_1516['a2'] + "_" +  nop_games_1516['a3'] + "_" +  nop_games_1516['a4'] + "_" +  nop_games_1516['a5'] + "_" + nop_games_1516['h1'] + "_" +  nop_games_1516['h2'] + "_" +  nop_games_1516['h3'] + "_" +  nop_games_1516['h4'] + "_" +  nop_games_1516['h5']

nop_games_1516['Davis on court'] = np.where(nop_games_1516['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1516['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2015-2016 season: 1481.0
# Davis on court
# On Court     20492
# Off Court    16997
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1617 = data_1617[data_1617['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1617_nop = nop_games_1617[nop_games_1617['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2016-2017 season: {davis_points1617_nop}")

nop_games_1617['On Court Players'] = nop_games_1617['a1'] + "_" +  nop_games_1617['a2'] + "_" +  nop_games_1617['a3'] + "_" +  nop_games_1617['a4'] + "_" +  nop_games_1617['a5'] + "_" + nop_games_1617['h1'] + "_" +  nop_games_1617['h2'] + "_" +  nop_games_1617['h3'] + "_" +  nop_games_1617['h4'] + "_" +  nop_games_1617['h5']

nop_games_1617['Davis on court'] = np.where(nop_games_1617['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1617['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2016-2017 season: 2099.0
# Davis on court
# On Court     25979
# Off Court    11967
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1718 = data_1718[data_1718['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1718_nop = nop_games_1718[nop_games_1718['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2017-2018 season: {davis_points1718_nop}")

nop_games_1718['On Court Players'] = nop_games_1718['a1'] + "_" +  nop_games_1718['a2'] + "_" +  nop_games_1718['a3'] + "_" +  nop_games_1718['a4'] + "_" +  nop_games_1718['a5'] + "_" + nop_games_1718['h1'] + "_" +  nop_games_1718['h2'] + "_" +  nop_games_1718['h3'] + "_" +  nop_games_1718['h4'] + "_" +  nop_games_1718['h5']

nop_games_1718['Davis on court'] = np.where(nop_games_1718['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1718['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2017-2018 season: 2381.0
# Davis on court
# On Court     29502
# Off Court    12751
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
nop_games_1819 = data_1819[data_1819['matchup'].str.contains('NOP')]

# Calculate total points for Thomas
davis_points1819_nop = nop_games_1819[nop_games_1819['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2018-2019 season: {davis_points1819_nop}")

nop_games_1819['On Court Players'] = nop_games_1819['a1'] + "_" +  nop_games_1819['a2'] + "_" +  nop_games_1819['a3'] + "_" +  nop_games_1819['a4'] + "_" +  nop_games_1819['a5'] + "_" + nop_games_1819['h1'] + "_" +  nop_games_1819['h2'] + "_" +  nop_games_1819['h3'] + "_" +  nop_games_1819['h4'] + "_" +  nop_games_1819['h5']

nop_games_1819['Davis on court'] = np.where(nop_games_1819['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

nop_games_1819['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2018-2019 season: 1452.0
# Davis on court
# Off Court    21041
# On Court     18462
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
lal_games_1920 = data_1920[data_1920['matchup'].str.contains('LAL')]

# Calculate total points for Thomas
davis_points1920_lal = lal_games_1920[lal_games_1920['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2019-2020 season: {davis_points1920_lal}")

lal_games_1920['On Court Players'] = lal_games_1920['a1'] + "_" +  lal_games_1920['a2'] + "_" +  lal_games_1920['a3'] + "_" +  lal_games_1920['a4'] + "_" +  lal_games_1920['a5'] + "_" + lal_games_1920['h1'] + "_" +  lal_games_1920['h2'] + "_" +  lal_games_1920['h3'] + "_" +  lal_games_1920['h4'] + "_" +  lal_games_1920['h5']

lal_games_1920['Davis on court'] = np.where(lal_games_1920['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

lal_games_1920['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2019-2020 season: 2200.0
# Davis on court
# On Court     28469
# Off Court    15021
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2021 = data_2021[data_2021['matchup'].str.contains('LAL')]

# Calculate total points for Thomas
davis_points2021_lal = lal_games_2021[lal_games_2021['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2020-2021 season: {davis_points2021_lal}")

lal_games_2021['On Court Players'] = lal_games_2021['a1'] + "_" +  lal_games_2021['a2'] + "_" +  lal_games_2021['a3'] + "_" +  lal_games_2021['a4'] + "_" +  lal_games_2021['a5'] + "_" + lal_games_2021['h1'] + "_" +  lal_games_2021['h2'] + "_" +  lal_games_2021['h3'] + "_" +  lal_games_2021['h4'] + "_" +  lal_games_2021['h5']

lal_games_2021['Davis on court'] = np.where(lal_games_2021['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

lal_games_2021['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2020-2021 season: 898.0
# Davis on court
# Off Court    23905
# On Court     12649
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2122 = data_2122[data_2122['matchup'].str.contains('LAL')]

# Calculate total points for Thomas
davis_points2122_lal = lal_games_2122[lal_games_2122['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2021-2022 season: {davis_points2122_lal}")

lal_games_2122['On Court Players'] = lal_games_2122['a1'] + "_" +  lal_games_2122['a2'] + "_" +  lal_games_2122['a3'] + "_" +  lal_games_2122['a4'] + "_" +  lal_games_2122['a5'] + "_" + lal_games_2021['h1'] + "_" +  lal_games_2122['h2'] + "_" +  lal_games_2122['h3'] + "_" +  lal_games_2122['h4'] + "_" +  lal_games_2122['h5']

lal_games_2122['Davis on court'] = np.where(lal_games_2122['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

lal_games_2122['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2021-2022 season: 927.0
# Davis on court
# On Court     37608
# Off Court     1562
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2223 = data_2223[data_2223['matchup'].str.contains('LAL')]

# Calculate total points for Thomas
davis_points2223_lal = lal_games_2223[lal_games_2223['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2022-2023 season: {davis_points2223_lal}")

lal_games_2223['On Court Players'] = lal_games_2223['a1'] + "_" +  lal_games_2223['a2'] + "_" +  lal_games_2223['a3'] + "_" +  lal_games_2223['a4'] + "_" +  lal_games_2223['a5'] + "_" + lal_games_2223['h1'] + "_" +  lal_games_2223['h2'] + "_" +  lal_games_2223['h3'] + "_" +  lal_games_2223['h4'] + "_" +  lal_games_2223['h5']

lal_games_2223['Davis on court'] = np.where(lal_games_2223['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

lal_games_2223['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2022-2023 season: 1836.0
# Davis on court
# On Court     24996
# Off Court    22234
# Name: count, dtype: int64

# %%
# Filter the dataframe for games where the Celtics played
lal_games_2324 = data_2324[data_2324['matchup'].str.contains('LAL')]

# Calculate total points for Thomas
davis_points2324_lal = lal_games_2324[lal_games_2324['player'] == 'Anthony Davis']['points'].sum()

print(f"Total points for Anthony Davis in the 2023-2024 season: {davis_points2324_lal}")

lal_games_2324['On Court Players'] = lal_games_2324['a1'] + "_" +  lal_games_2324['a2'] + "_" +  lal_games_2324['a3'] + "_" +  lal_games_2324['a4'] + "_" +  lal_games_2324['a5'] + "_" + lal_games_2324['h1'] + "_" +  lal_games_2324['h2'] + "_" +  lal_games_2324['h3'] + "_" +  lal_games_2324['h4'] + "_" +  lal_games_2324['h5']

lal_games_2324['Davis on court'] = np.where(lal_games_2324['On Court Players'].str.contains('Anthony Davis'), "On Court", "Off Court")

lal_games_2324['Davis on court'].value_counts()
# Out:
# Total points for Anthony Davis in the 2023-2024 season: 2076.0
# Davis on court
# On Court     28311
# Off Court    12684
# Name: count, dtype: int64

# %%
# prompt: create a chart where it number of on cout per game as a bar and a line of total points   Thomas earns.

import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
seasons = ['2013-2014', '2014-2015','2015-2016','2016-2017','2017-2018','2018-2019','2019-2020','2020-2021','2021-2022','2022-2023','2023-2024']
on_court_counts = [21938,24081,20492,25979,29502,21041,28469,23905,37608,24996,28311]  # Number of times on court per game
davis_points = [davis_points1314_nop, davis_points1415_nop, davis_points1516_nop, davis_points1617_nop, davis_points1718_nop,davis_points1819_nop,davis_points1920_lal,
                davis_points2021_lal, davis_points2122_lal, davis_points2223_lal, davis_points2324_lal]
      # Total points earned by Thomas

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(seasons, on_court_counts, label='On Court Counts')

# Create the line chart
plt.plot(seasons, davis_points, marker='o', linestyle='-', color='red', label='Davis Points')

# Customize the chart
plt.xlabel('Teams/Seasons')
plt.ylabel('Values')
plt.title('On Court Count vs. Davis Points')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()  # Adjust layout to prevent labels from overlapping


# Show the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
seasons = ['2013-2014', '2014-2015','2015-2016','2016-2017','2017-2018','2018-2019','2019-2020','2020-2021','2021-2022','2022-2023','2023-2024']
on_court_counts = [21938,24081,20492,25979,29502,21041,28469,23905,37608,24996,28311]  # Number of times on court per game
davis_points = [davis_points1314_nop, davis_points1415_nop, davis_points1516_nop, davis_points1617_nop, davis_points1718_nop,davis_points1819_nop,davis_points1920_lal,
                davis_points2021_lal, davis_points2122_lal, davis_points2223_lal, davis_points2324_lal]
      # Total points earned by Thomas


# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create the bar chart for on-court counts
ax1.bar(seasons, on_court_counts, label='On Court Counts', color='lightblue')

# Set labels for the first y-axis
ax1.set_xlabel('Seasons')
ax1.set_ylabel('On Court Counts', color='blue')

# Create a second y-axis for the Thomas points line chart
ax2 = ax1.twinx()
ax2.plot(seasons, davis_points, marker='o', linestyle='-', color='red', label='Davis Points')

# Set labels for the second y-axis
ax2.set_ylabel('Davis Points', color='red')

# Customize the chart
ax1.set_title('On Court Count vs. Davis Points')
ax1.tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

# Show legends for both axes
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the chart
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Display the plot
plt.show()

# %%
# prompt: sac_games_1314= sac_games_1314[sac_games_1314['Thomas on court']=='Off Court'].sum(point)

nop_games_1314_off = nop_games_1314[nop_games_1314['Davis on court'] == 'Off Court']['points'].sum()
nop_games_1415_off = nop_games_1415[nop_games_1415['Davis on court'] == 'Off Court']['points'].sum()
nop_games_1516_off = nop_games_1516[nop_games_1516['Davis on court'] == 'Off Court']['points'].sum()
nop_games_1617_off = nop_games_1617[nop_games_1617['Davis on court'] == 'Off Court']['points'].sum()
nop_games_1718_off = nop_games_1718[nop_games_1718['Davis on court'] == 'Off Court']['points'].sum()
nop_games_1819_off = nop_games_1819[nop_games_1819['Davis on court'] == 'Off Court']['points'].sum()
lal_games_1920_off = lal_games_1920[lal_games_1920['Davis on court'] == 'Off Court']['points'].sum()
lal_games_2021_off = lal_games_2021[lal_games_2021['Davis on court'] == 'Off Court']['points'].sum()
lal_games_2122_off = lal_games_2122[lal_games_2122['Davis on court'] == 'Off Court']['points'].sum()
lal_games_2223_off = lal_games_2223[lal_games_2223['Davis on court'] == 'Off Court']['points'].sum()
lal_games_2324_off = lal_games_2324[lal_games_2324['Davis on court'] == 'Off Court']['points'].sum()

# %%
# prompt: sac_games_1314_off
# phx_games_1415_off
# bos_games_1415_off
# bos_games_1516_off
# bos_games_1617_off
# cle_games_1718_off
# lal_games_1718_off- using these value , create a bar chart

import matplotlib.pyplot as plt

# Data provided in the prompt
seasons = ['2013-2014', '2014-2015','2015-2016','2016-2017','2017-2018','2018-2019','2019-2020','2020-2021','2021-2022','2022-2023','2023-2024']
off_court_points = [nop_games_1314_off, nop_games_1415_off, nop_games_1516_off, nop_games_1617_off, nop_games_1718_off, nop_games_1819_off,
                    lal_games_1920_off, lal_games_2021_off, lal_games_2122_off, lal_games_2223_off, lal_games_2324_off]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(seasons, off_court_points)

# Customize the chart
plt.xlabel('Teams/Seasons')
plt.ylabel('Total Points (Davis Off Court)')
plt.title('Total Points Scored When Davis Was Off the Court')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Show the chart
plt.show()

# %%
datalist = ('nop_games_1314', 'nop_games_1415', 'nop_games_1516', 'nop_games_1617', 'nop_games_1718', 'nop_games_1819',
            'lal_games_1920', 'lal_games_2021', 'lal_games_2122', 'lal_games_2223', 'lal_games_2324')

# %%
# prompt: loop through datalist, calculate these import pandas as pd
# # Filter to only Jayson Tatum's shot attempts
# thomas_shots = sac_games_1314[
#     (data_1617['player'] == 'Isaiah Thomas') &
#     (data_1617['event_type'] == 'shot')
# ]
# # Basic shot stats
# total_fga = len(thomas_shots)
# made_shots = thomas_shots[thomas_shots['result'] == 'made']
# missed_shots = thomas_shots[thomas_shots['result'] == 'missed']
# fgm = len(made_shots)
# # 3-point attempts and makes
# three_point_attempts = thomas_shots[thomas_shots['points'] == 3]
# three_point_makes = three_point_attempts[three_point_attempts['result'] == 'made']
# # Shooting efficiency metrics
# fg_pct = fgm / total_fga if total_fga > 0 else 0
# three_pt_pct = len(three_point_makes) / len(three_point_attempts) if len(three_point_attempts) > 0 else 0
# efg_pct = (fgm + 0.5 * len(three_point_makes)) / total_fga if total_fga > 0 else 0
# # Shot distance
# avg_shot_distance = thomas_shots['shot_distance'].mean()
# # Assisted FG Rate
# made_assisted = made_shots[~made_shots['assist'].isna()]
# assist_rate = len(made_assisted) / fgm if fgm > 0 else 0
# # Final output
# print(f" Thomas Shooting Efficiency:")
# print(f"Total FG Attempts: {total_fga}")
# print(f"FG%: {fg_pct:.3f}")
# print(f"3P%: {three_pt_pct:.3f}")
# print(f"eFG%: {efg_pct:.3f}")
# print(f"Average Shot Distance: {avg_shot_distance:.2f} feet")
# print(f"Assisted FG Rate: {assist_rate:.2%}")

for data in datalist:
  # Assuming each item in datalist corresponds to a DataFrame
  # and contains columns like 'player', 'event_type', 'result', 'points', 'shot_distance', and 'assist'.
  # Replace with actual DataFrame names
  try:
    df = eval(data) # Evaluate the string as a variable name
    davis_shots = df[
        (df['player'] == 'Anthony Davis') &
        (df['event_type'] == 'shot')
    ]
    total_fga = len(davis_shots)
    made_shots = davis_shots[davis_shots['result'] == 'made']
    missed_shots = davis_shots[davis_shots['result'] == 'missed']
    fgm = len(made_shots)
    three_point_attempts = davis_shots[davis_shots['points'] == 3]
    three_point_makes = three_point_attempts[three_point_attempts['result'] == 'made']

    fg_pct = fgm / total_fga if total_fga > 0 else 0
    three_pt_pct = len(three_point_makes) / len(three_point_attempts) if len(three_point_attempts) > 0 else 0
    efg_pct = (fgm + 0.5 * len(three_point_makes)) / total_fga if total_fga > 0 else 0
    avg_shot_distance = davis_shots['shot_distance'].mean()
    made_assisted = made_shots[~made_shots['assist'].isna()]
    assist_rate = len(made_assisted) / fgm if fgm > 0 else 0

    print(f"Thomas Shooting Efficiency for {data}:")
    print(f"Total FG Attempts: {total_fga}")
    print(f"FG%: {fg_pct:.3f}")
    print(f"eFG%: {efg_pct:.3f}")
    print(f"Average Shot Distance: {avg_shot_distance:.2f} feet")
    print(f"Assisted FG Rate: {assist_rate:.2%}")
    print("-" * 20)

  except NameError:
    print(f"DataFrame '{data}' not found.")
  except KeyError as e:
    print(f"Error: DataFrame '{data}' missing key {e}.")
# Out:
# Thomas Shooting Efficiency for nop_games_1314:
# Total FG Attempts: 1005
# FG%: 0.519
# eFG%: 0.520
# Average Shot Distance: 8.30 feet
# Assisted FG Rate: 66.86%
# --------------------
# Thomas Shooting Efficiency for nop_games_1415:
# Total FG Attempts: 1286
# FG%: 0.536
# eFG%: 0.536
# Average Shot Distance: 9.47 feet
# Assisted FG Rate: 71.55%
# --------------------
# Thomas Shooting Efficiency for nop_games_1516:
# Total FG Attempts: 1136
# FG%: 0.493
# eFG%: 0.508
# Average Shot Distance: 10.77 feet
# Assisted FG Rate: 74.11%
# --------------------
# Thomas Shooting Efficiency for nop_games_1617:
# Total FG Attempts: 1526
# FG%: 0.505
# eFG%: 0.518
# Average Shot Distance: 10.60 feet
# Assisted FG Rate: 66.23%
# --------------------
# Thomas Shooting Efficiency for nop_games_1718:
# Total FG Attempts: 1666
# FG%: 0.532
# eFG%: 0.550
# Average Shot Distance: 9.70 feet
# Assisted FG Rate: 72.57%
# --------------------
# Thomas Shooting Efficiency for nop_games_1819:
# ...

# %%
# prompt: create visulazation to illustrate these number

import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
teams = [
    'nop_games_1314', 'nop_games_1415', 'nop_games_1516', 'nop_games_1617', 'nop_games_1718', 'nop_games_1819',
    'lal_games_1920', 'lal_games_2021', 'lal_games_2122', 'lal_games_2223', 'lal_games_2324'
]
fg_pct = [0.519, 0.536, 0.493, 0.505, 0.532, 0.517, 0.520, 0.481, 0.532, 0.553, 0.561]
efg_pct = [0.520, 0.536, 0.508, 0.518, 0.550, 0.540, 0.552, 0.501, 0.542, 0.563, 0.571]
avg_shot_distance = [8.30, 9.47, 10.77, 10.60, 9.70, 9.80, 11.32, 11.67, 9.56, 8.13, 7.81]
assist_rate = [66.86, 71.55, 74.11, 66.23, 72.57, 65.28, 62.70, 62.50, 65.41, 65.79, 68.01]


# Create the figure and axes
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot FG% and eFG% as line charts
ax1.plot(teams, fg_pct, marker='o', linestyle='-', color='blue', label='FG%')
ax1.plot(teams, efg_pct, marker='s', linestyle='-', color='green', label='eFG%')


# Create a second y-axis for average shot distance
ax2 = ax1.twinx()
ax2.plot(teams, avg_shot_distance, marker='^', linestyle='-', color='red', label='Avg Shot Distance')

# Create a third y-axis for assist rate
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.plot(teams, assist_rate, marker='x', linestyle='-', color='purple', label='Assist Rate')

# Set labels and title
ax1.set_xlabel('Seasons')
ax1.set_ylabel('FG% and eFG%', color='blue')
ax2.set_ylabel('Avg Shot Distance (feet)', color='red')
ax3.set_ylabel('Assist Rate', color='purple')

plt.title('Thomas Shooting Performance Across Teams/Seasons')


# Show legends for all axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax3.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc="upper left")


# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
# prompt: the chart is accurate but look not good, draw another chart

import matplotlib.pyplot as plt

teams = [
    'nop_games_1314', 'nop_games_1415', 'nop_games_1516', 'nop_games_1617', 'nop_games_1718', 'nop_games_1819',
    'lal_games_1920', 'lal_games_2021', 'lal_games_2122', 'lal_games_2223', 'lal_games_2324'
]
fg_pct = [0.519, 0.536, 0.493, 0.505, 0.532, 0.517, 0.520, 0.481, 0.532, 0.553, 0.561]
efg_pct = [0.520, 0.536, 0.508, 0.518, 0.550, 0.540, 0.552, 0.501, 0.542, 0.563, 0.571]
avg_shot_distance = [8.30, 9.47, 10.77, 10.60, 9.70, 9.80, 11.32, 11.67, 9.56, 8.13, 7.81]
assist_rate = [66.86, 71.55, 74.11, 66.23, 72.57, 65.28, 62.70, 62.50, 65.41, 65.79, 68.01]

# Create subplots for a better layout
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Plot FG% and eFG%
axes[0, 0].plot(teams, fg_pct, marker='o', linestyle='-', color='blue', label='FG%')
axes[0, 0].plot(teams, efg_pct, marker='s', linestyle='-', color='green', label='eFG%')
axes[0, 0].set_xlabel('Teams/Seasons')
axes[0, 0].set_ylabel('Percentage')
axes[0, 0].set_title('FG% and eFG% Over Time')
axes[0, 0].legend()
axes[0, 0].tick_params(axis='x', rotation=45)

# Plot average shot distance
axes[0, 1].plot(teams, avg_shot_distance, marker='^', linestyle='-', color='red', label='Avg Shot Distance')
axes[0, 1].set_xlabel('Teams/Seasons')
axes[0, 1].set_ylabel('Distance (feet)')
axes[0, 1].set_title('Average Shot Distance Over Time')
axes[0, 1].legend()
axes[0, 1].tick_params(axis='x', rotation=45)


# Plot assist rate
axes[1, 0].plot(teams, assist_rate, marker='x', linestyle='-', color='purple', label='Assist Rate')
axes[1, 0].set_xlabel('Teams/Seasons')
axes[1, 0].set_ylabel('Rate')
axes[1, 0].set_title('Assist Rate Over Time')
axes[1, 0].legend()
axes[1, 0].tick_params(axis='x', rotation=45)

# Remove the unused subplot
fig.delaxes(axes[1, 1])

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
#thomas_event1314_sac = sac_games_1314[sac_games_1314['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1314_sac

# %%
#thomas_event1415_phx = phx_games_1415[phx_games_1415['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1415_phx

# %%
#thomas_event1415_bos= bos_games_1415[bos_games_1415['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1415_bos

# %%
#thomas_event1516_bos= bos_games_1516[bos_games_1516['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_points1516_bos

# %%
#thomas_event1617_bos= bos_games_1617[bos_games_1617['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1617_bos

# %%
#thomas_event1718_cle= cle_games_1718[cle_games_1718['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1718_cle

# %%
#thomas_event1718_lal= lal_games_1718[lal_games_1718['player'] == 'Isaiah Thomas']['event_type'].value_counts()
#thomas_event1718_lal

# %%
# prompt: give me a list of who assist Thomas when he is a player

# Assuming 'bos_games_1415', 'bos_games_1516', 'bos_games_1617', 'cle_games_1718', and 'lal_games_1718'
# are your DataFrames.  Replace with your actual DataFrame names.

def get_assisters(df, player):
    """
    Identifies players who assisted the specified player in a DataFrame
    """
    assisters = df[df['assist'] == player]['player'].unique()
    return list(assisters)

# Example Usage
# For the 2014-15 Boston Celtics games:
davis_assisters_1314 = get_assisters(nop_games_1314, 'Anthony Davis')
print(f"Players who assisted Thomas in 2013-2014 season for BOS: {davis_assisters_1314}")

davis_assisters_1415 = get_assisters(nop_games_1415, 'Anthony Davis')
print(f"Players who assisted Thomas in 2014-2015 season for BOS: {davis_assisters_1415}")

davis_assisters_1516 = get_assisters(nop_games_1516, 'Anthony Davis')
print(f"Players who assisted Thomas in 2015-2016 season for BOS: {davis_assisters_1516}")

davis_assisted_1617 = get_assisters(nop_games_1617, 'Anthony Davis')
print(f"Players who assisted Thomas in 2016-2017 season for BOS: {davis_assisted_1617}")

davis_assisted_1718 = get_assisters(nop_games_1718, 'Anthony Davis')
print(f"Players who assisted Thomas in 2017-2018 season for BOS: {davis_assisted_1718}")

davis_assisted_1819 = get_assisters(nop_games_1819, 'Anthony Davis')
print(f"Players who assisted Thomas in 2018-2019 season for BOS: {davis_assisted_1819}")

davis_assisted_1920 = get_assisters(lal_games_1920, 'Anthony Davis')
print(f"Players who assisted Thomas in 2019-2020 season for LAL: {davis_assisted_1920}")

davis_assisted_2021 = get_assisters(lal_games_2021, 'Anthony Davis')
print(f"Players who assisted Thomas in 2020-2021 season for LAL: {davis_assisted_2021}")

davis_assisted_2122 = get_assisters(lal_games_2122, 'Anthony Davis')
print(f"Players who assisted Thomas in 2021-2022 season for LAL: {davis_assisted_2122}")

davis_assisted_2223 = get_assisters(lal_games_2223, 'Anthony Davis')
print(f"Players who assisted Thomas in 2022-2023 season for LAL: {davis_assisted_2223}")

davis_assisted_2324 = get_assisters(lal_games_2324, 'Anthony Davis')
print(f"Players who assisted Thomas in 2023-2024 season for LAL: {davis_assisted_2324}")
# Out:
# Players who assisted Thomas in 2013-2014 season for BOS: ['Jrue Holiday', 'Anthony Morrow', 'Ryan Anderson', 'Brian Roberts', 'Al-Farouq Aminu', 'Greg Stiemsma', 'Eric Gordon', 'Austin Rivers', 'Tyreke Evans', 'Alexis Ajinca', 'Luke Babbitt', 'Darius Miller', 'Jason Smith', 'Lou Amundson']
# Players who assisted Thomas in 2014-2015 season for BOS: ['Jrue Holiday', 'Luke Babbitt', 'Dante Cunningham', 'Ryan Anderson', 'Tyreke Evans', 'Omer Asik', 'Eric Gordon', 'Quincy Pondexter', 'Norris Cole', 'Alexis Ajinca', 'Toney Douglas', 'Austin Rivers', 'John Salmons']
# Players who assisted Thomas in 2015-2016 season for BOS: ['Tyreke Evans', 'Ish Smith', 'Jrue Holiday', 'Norris Cole', 'Eric Gordon', 'Omer Asik', 'Alonzo Gee', 'Dante Cunningham', 'Ryan Anderson', 'Bryce Dejean-Jones', 'Toney Douglas', 'Alexis Ajinca', 'Luke Babbitt', 'Kendrick Perkins']
# ...

# %%
# prompt: count who is the assist Thomas the most for each season

def count_assisters(df, player):
    """Counts assists for a given player by other players."""
    assist_counts = df[df['assist'] == player]['player'].value_counts()
    return assist_counts

# Assuming your dataframes are named as in the provided code
seasons = {
    '2014-15': nop_games_1415,
    '2015-16': nop_games_1516,
    '2016-17': nop_games_1617,
    '2017-18': nop_games_1718,
    '2018-19': nop_games_1718,
    '2019-20': lal_games_1920,
    '2021-22': lal_games_2122,
    '2022-23': lal_games_2223,
    '2023-24': lal_games_2324
}

for season, df in seasons.items():
    assist_counts = count_assisters(df, 'Anthony Davis')
    print(f"Assists for Anthony Davis in {season}:")
    if not assist_counts.empty:  # Check if assist_counts is not empty
        print(assist_counts)
    else:
        print("No assists recorded for Anothony Davis this season.")
    print("-" * 20)
# Out:
# Assists for Anthony Davis in 2014-15:
# player
# Tyreke Evans        39
# Eric Gordon         28
# Jrue Holiday        18
# Dante Cunningham    14
# Quincy Pondexter    13
# Norris Cole         13
# Omer Asik           11
# Ryan Anderson       10
# Austin Rivers        4
# Luke Babbitt         3
# Alexis Ajinca        2
# Toney Douglas        1
# John Salmons         1
# Name: count, dtype: int64
# --------------------
# Assists for Anthony Davis in 2015-16:
# player
# Eric Gordon           21
# Jrue Holiday          18
# Norris Cole           17
# Dante Cunningham      10
# Alonzo Gee             8
# Ryan Anderson          8
# Tyreke Evans           7
# Ish Smith              7
# Toney Douglas          6
# Omer Asik              5
# Bryce Dejean-Jones     4
# Luke Babbitt           3
# Alexis Ajinca          1
# Kendrick Perkins       1
# Name: count, dtype: int64
# --------------------
# Assists for Anthony Davis in 2016-17:
# player
# Jrue Holiday          31
# ...

# %% [markdown]
# Shotting efficiency
# Assited vs unassisted
#
#
#
# Start with Final Score
# Then ....per ...- break down in detail and really think about it. TRy to compute something from the available data ( eg plus minus metric)
#
# We could tell that Thomas is a main shot, calculate how many % he successfully score, vs when other teammate shot. ( idea here is maybe he gets more attention and other players have more space to shot)
#
# find the game where Jae Crowder is not in the game, how well Thomas shot?
#
# show how well the team does without Thomas
#
# Only focus on regular season
#
# when analyzing event_type, **free throw could be taken off**
#
# could calculate game per minute, how long does Thomas take to shot?

# %% [markdown]
# --------------------------------

# %%
pd.pivot_table(data= nop_games_1314,
               index = ['player', 'team'],
               values = 'points',
               aggfunc = np.sum).reset_index().sort_values(by = 'points',  ascending = False).head(10)
# Out:
#               player team  points
# 38     Anthony Davis  NOP  1394.0
# 457     Tyreke Evans  NOP  1043.0
# 144      Eric Gordon  NOP   988.0
# 72     Brian Roberts  NOP   677.0
# 47    Anthony Morrow  NOP   636.0
# 6    Al-Farouq Aminu  NOP   572.0
# 55     Austin Rivers  NOP   530.0
# 252     Jrue Holiday  NOP   487.0
# 398    Ryan Anderson  NOP   436.0
# 11     Alexis Ajinca  NOP   328.0

# %%
datalist = ('nop_games_1314', 'nop_games_1415', 'nop_games_1516', 'nop_games_1617', 'nop_games_1718', 'nop_games_1819',
    'lal_games_1920', 'lal_games_2021', 'lal_games_2122', 'lal_games_2223', 'lal_games_2324')

# %%
nop_games_1314.head()
# Out:
#       game_id                data_set        date              a1  \
# 465  21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 466  21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 467  21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 468  21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
# 469  21300323  2013-14 Regular Season  2013-12-11  Andre Drummond
#
#                    a2          a3           a4                        a5  \
# 465  Brandon Jennings  Josh Smith  Greg Monroe  Kentavious Caldwell-Pope
# 466  Brandon Jennings  Josh Smith  Greg Monroe  Kentavious Caldwell-Pope
# 467  Brandon Jennings  Josh Smith  Greg Monroe  Kentavious Caldwell-Pope
# 468  Brandon Jennings  Josh Smith  Greg Monroe  Kentavious Caldwell-Pope
# 469  Brandon Jennings  Josh Smith  Greg Monroe  Kentavious Caldwell-Pope
#
#               h1               h2            h3             h4           h5  \
# ...

# %%
nop_games_1314['MinuteOfGame'] = (nop_games_1314['period'] - 1)*12 + nop_games_1314['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1314['Posession'] = np.where(nop_games_1314['team'] == 'NOP', 'Offense', 'Defense')
temp1314 = pd.pivot_table(data= nop_games_1314,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1314['plus_minus'] = temp1314['Offense'] - temp1314['Defense']

np.round(pd.pivot_table(data= temp1314,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.07
# 1               On Court       -0.04

# %%
nop_games_1415['MinuteOfGame'] = (nop_games_1415['period'] - 1)*12 + nop_games_1415['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1415['Posession'] = np.where(nop_games_1415['team'] == 'NOP', 'Offense', 'Defense')
temp1415_1 = pd.pivot_table(data= nop_games_1415,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1415_1['plus_minus'] = temp1415_1['Offense'] - temp1415_1['Defense']

np.round(pd.pivot_table(data= temp1415_1,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.13
# 1               On Court        0.09

# %%
nop_games_1415['MinuteOfGame'] = (nop_games_1415['period'] - 1)*12 + nop_games_1415['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1415['Posession'] = np.where(nop_games_1415['team'] == 'NOP', 'Offense', 'Defense')
temp1415 = pd.pivot_table(data= nop_games_1415,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1415['plus_minus'] = temp1415['Offense'] - temp1415['Defense']

np.round(pd.pivot_table(data= temp1415,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.13
# 1               On Court        0.09

# %%
nop_games_1516['MinuteOfGame'] = (nop_games_1516['period'] - 1)*12 + nop_games_1516['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1516['Posession'] = np.where(nop_games_1516['team'] == 'NOP', 'Offense', 'Defense')
temp1516 = pd.pivot_table(data= nop_games_1516,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1516['plus_minus'] = temp1516['Offense'] - temp1516['Defense']

np.round(pd.pivot_table(data= temp1516,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.06
# 1               On Court       -0.09

# %%
nop_games_1617['MinuteOfGame'] = (nop_games_1617['period'] - 1)*12 + nop_games_1617['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1617['Posession'] = np.where(nop_games_1617['team'] == 'NOP', 'Offense', 'Defense')
temp1617 = pd.pivot_table(data= nop_games_1617,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1617['plus_minus'] = temp1617['Offense'] - temp1617['Defense']

np.round(pd.pivot_table(data= temp1617,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.16
# 1               On Court        0.02

# %%
nop_games_1718['MinuteOfGame'] = (nop_games_1718['period'] - 1)*12 +nop_games_1718['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1718['Posession'] = np.where(nop_games_1718['team'] == 'NOP', 'Offense', 'Defense')
temp1718 = pd.pivot_table(data= nop_games_1718,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1718['plus_minus'] = temp1718['Offense'] - temp1718['Defense']

np.round(pd.pivot_table(data= temp1718,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.15
# 1               On Court        0.09

# %%
nop_games_1718['MinuteOfGame'] = (nop_games_1718['period'] - 1)*12 + nop_games_1718['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1718['Posession'] = np.where(nop_games_1718['team'] == 'NOP', 'Offense', 'Defense')
temp1718_1 = pd.pivot_table(data= nop_games_1718,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1718_1['plus_minus'] = temp1718_1['Offense'] - temp1718_1['Defense']

np.round(pd.pivot_table(data= temp1718_1,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.15
# 1               On Court        0.09

# %%
nop_games_1819['MinuteOfGame'] = (nop_games_1819['period'] - 1)*12 + nop_games_1819['elapsed'].str.split(':', expand = True)[1].astype(int)
nop_games_1819['Posession'] = np.where(nop_games_1819['team'] == 'NOP', 'Offense', 'Defense')
temp1819 = pd.pivot_table(data= nop_games_1819,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1819['plus_minus'] = temp1819['Offense'] - temp1819['Defense']

np.round(pd.pivot_table(data= temp1819,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.11
# 1               On Court        0.07

# %%
lal_games_1920['MinuteOfGame'] = (lal_games_1920['period'] - 1)*12 + lal_games_1920['elapsed'].str.split(':', expand = True)[1].astype(int)
lal_games_1920['Posession'] = np.where(lal_games_1920['team'] == 'LAL', 'Offense', 'Defense')
temp1920 = pd.pivot_table(data= lal_games_1920,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp1920['plus_minus'] = temp1920['Offense'] - temp1920['Defense']

np.round(pd.pivot_table(data= temp1920,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court        0.08
# 1               On Court        0.14

# %%
lal_games_2021['MinuteOfGame'] = (lal_games_2021['period'] - 1)*12 + lal_games_2021['elapsed'].str.split(':', expand = True)[1].astype(int)
lal_games_2021['Posession'] = np.where(lal_games_2021['team'] == 'LAL', 'Offense', 'Defense')
temp2021 = pd.pivot_table(data= lal_games_2021,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp2021['plus_minus'] = temp2021['Offense'] - temp2021['Defense']

np.round(pd.pivot_table(data= temp2021,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court        0.02
# 1               On Court        0.07

# %%
lal_games_2122['MinuteOfGame'] = (lal_games_2122['period'] - 1)*12 + lal_games_2122['elapsed'].str.split(':', expand = True)[1].astype(int)
lal_games_2122['Posession'] = np.where(lal_games_2122['team'] == 'LAL', 'Offense', 'Defense')
temp2122 = pd.pivot_table(data= lal_games_2122,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp2122['plus_minus'] = temp2122['Offense'] - temp2122['Defense']

np.round(pd.pivot_table(data= temp2122,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court        0.04
# 1               On Court       -0.07

# %%
lal_games_2223['MinuteOfGame'] = (lal_games_2223['period'] - 1)*12 + lal_games_2223['elapsed'].str.split(':', expand = True)[1].astype(int)
lal_games_2223['Posession'] = np.where(lal_games_2223['team'] == 'LAL', 'Offense', 'Defense')
temp2223 = pd.pivot_table(data= lal_games_2223,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp2223['plus_minus'] = temp2223['Offense'] - temp2223['Defense']

np.round(pd.pivot_table(data= temp2223,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.07
# 1               On Court        0.10

# %%
lal_games_2324['MinuteOfGame'] = (lal_games_2324['period'] - 1)*12 + lal_games_2324['elapsed'].str.split(':', expand = True)[1].astype(int)
lal_games_2324['Posession'] = np.where(lal_games_2324['team'] == 'LAL', 'Offense', 'Defense')
temp2324 = pd.pivot_table(data= lal_games_2324,
               index = ['MinuteOfGame', 'game_name', 'Davis on court'],
               columns = ['Posession'],
               values = 'points',
               aggfunc = np.sum).reset_index()

temp2324['plus_minus'] = temp2324['Offense'] - temp2324['Defense']

np.round(pd.pivot_table(data= temp2324,
               index = [ 'Davis on court'],
               values = ['plus_minus'],
               aggfunc = np.mean).reset_index(),2)
# Out:
# Posession Davis on court  plus_minus
# 0              Off Court       -0.07
# 1               On Court        0.05

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combine plus-minus data into a single DataFrame
combined_plus_minus = pd.concat(
    [data for data in plus_minus_data.values()],
    keys=plus_minus_data.keys(),
    names=['Season', 'Index']
).reset_index(level=0)

# Define Lakers color palette
lakers_palette = {'On Court': '#552583', 'Off Court': '#FDB927'}  # Purple and Gold

# Create the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(
    x='Season',
    y='plus_minus',
    hue='Davis on court',
    data=combined_plus_minus,
    palette=lakers_palette
)

plt.title('Davis on Court vs. Off Court Plus-Minus Across Seasons')
plt.xlabel('Seasons')
plt.ylabel('Plus-Minus')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.tight_layout()
plt.show()

# %%
# prompt: create a v=bart chart for plus minus data from 2013- 2019

import matplotlib.pyplot as plt

# Sample plus-minus data (replace with your actual data)
seasons = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19']
plus_minus_on_court = [2.5, 3.1, 1.8, 2.9, 3.5, 2.2]
plus_minus_off_court = [1.2, 1.9, 0.8, 1.5, 2.1, 1.0]

# Create the bar chart
plt.figure(figsize=(10, 6))
X_axis = np.arange(len(seasons))
plt.bar(X_axis - 0.2, plus_minus_on_court, 0.4, label='Davis On Court')
plt.bar(X_axis + 0.2, plus_minus_off_court, 0.4, label='Davis Off Court')

# Customize the chart
plt.xticks(X_axis, seasons)
plt.xlabel("Seasons")
plt.ylabel("Plus-Minus")
plt.title("Anthony Davis Plus-Minus (On/Off Court)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Combine plus-minus data
combined_plus_minus = pd.concat(
    [data for data in plus_minus_data.values()],
    keys=plus_minus_data.keys(),
    names=['Season', 'Index']
).reset_index(level=0)

# Helper: extract start year
def get_start_year(season_str):
    return int(season_str.split('-')[0])

# Create hue label
combined_plus_minus['color_label'] = combined_plus_minus['Season'] + " - " + combined_plus_minus['Davis on court']

# Custom color palette by team era
color_map = {}
for label in combined_plus_minus['color_label'].unique():
    season, status = label.split(' - ')
    year = get_start_year(season)
    if year < 2019:
        color_map[label] = '#0C2340' if status == 'On Court' else '#C8102E'  # Navy / Red
    else:
        color_map[label] = '#552583' if status == 'On Court' else '#FDB927'  # Purple / Yellow

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(
    x='Season',
    y='plus_minus',
    hue='color_label',
    data=combined_plus_minus,
    palette=color_map,
    dodge=0.05,
    width=0.99999
)

# Remove the autogenerated legend
plt.legend().remove()


# Final polish
plt.title('Davis On vs. Off Court Plus-Minus by Season (2013–2024)', fontsize=14, fontweight='bold')
plt.xlabel('Seasons')
plt.ylabel('Plus-Minus')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # LAL before and after Davis join

# %%
lal_games_1314 = data_1314[data_1314['matchup'].str.contains('LAL')]
lal_games_1415 = data_1415[data_1415['matchup'].str.contains('LAL')]
lal_games_1516 = data_1516[data_1516['matchup'].str.contains('LAL')]
lal_games_1617 = data_1617[data_1617['matchup'].str.contains('LAL')]
lal_games_1718 = data_1718[data_1718['matchup'].str.contains('LAL')]
lal_games_1819 = data_1819[data_1819['matchup'].str.contains('LAL')]

# %%
lakers_2013_14 = [
    "Kobe Bryant", "Pau Gasol", "Steve Nash", "Jodie Meeks", "Jordan Farmar",
    "Nick Young", "Wesley Johnson", "Chris Kaman", "Xavier Henry", "Ryan Kelly",
    "Robert Sacre", "Kendall Marshall", "Kent Bazemore", "MarShon Brooks",
    "Steve Blake", "Shawne Williams", "Manny Harris", "Elias Harris"
]

lakers_2014_15 = [
    "Kobe Bryant", "Jordan Hill", "Jeremy Lin", "Carlos Boozer", "Wesley Johnson",
    "Nick Young", "Ed Davis", "Wayne Ellington", "Ronnie Price", "Robert Sacre",
    "Julius Randle", "Ryan Kelly", "Jordan Clarkson", "Xavier Henry", "Tarik Black",
    "Jabari Brown"
]

lakers_2015_16 = [
    "Kobe Bryant", "Jordan Clarkson", "D'Angelo Russell", "Julius Randle",
    "Roy Hibbert", "Lou Williams", "Brandon Bass", "Larry Nance Jr.",
    "Metta World Peace", "Marcelo Huertas", "Ryan Kelly", "Tarik Black",
    "Anthony Brown", "Robert Sacre"
]

lakers_2016_17 = [
    "D'Angelo Russell", "Nick Young", "Luol Deng", "Julius Randle", "Timofey Mozgov",
    "Jordan Clarkson", "Brandon Ingram", "Larry Nance Jr.", "Tarik Black",
    "Jose Calderon", "Thomas Robinson", "Ivica Zubac", "Metta World Peace",
    "David Nwaba", "Tyler Ennis", "Corey Brewer", "Marcelo Huertas", "Lou Williams"
]

lakers_2017_18 = [
    "Lonzo Ball", "Kentavious Caldwell-Pope", "Brandon Ingram", "Julius Randle",
    "Brook Lopez", "Kyle Kuzma", "Josh Hart", "Larry Nance Jr.", "Jordan Clarkson",
    "Tyler Ennis", "Andrew Bogut", "Corey Brewer", "Ivica Zubac", "Alex Caruso",
    "Channing Frye", "Isaiah Thomas", "Gary Payton II", "Travis Wear",
    "Thomas Bryant", "Nigel Hayes", "Andre Ingram"
]

lakers_2018_19 = [
    "LeBron James", "Brandon Ingram", "Kyle Kuzma", "JaVale McGee", "Rajon Rondo",
    "Kentavious Caldwell-Pope", "Josh Hart", "Lance Stephenson", "Tyson Chandler",
    "Lonzo Ball", "Reggie Bullock", "Ivica Zubac", "Michael Beasley",
    "Moritz Wagner", "Alex Caruso", "Isaac Bonga", "Johnathan Williams", "Mike Muscala"
]

# %%
# prompt: calcualte how many point in total when player is belong in celtics_players_2013_2014 list

# Filter the dataframe for games where the Celtics played

# Calculate total points for Celtics players
total_points1314_lal = 0
for player in lakers_2013_14:
  player_points = lal_games_1314[lal_games_1314['player'] == player]['points'].sum()
  total_points1314_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1314_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 7773.0

# %%
total_points1415_lal = 0
for player in lakers_2014_15:
  player_points = lal_games_1415[lal_games_1415['player'] == player]['points'].sum()
  total_points1415_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1415_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 8006.0

# %%
total_points1516_lal = 0
for player in lakers_2015_16:
  player_points = lal_games_1516[lal_games_1516['player'] == player]['points'].sum()
  total_points1516_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1516_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 7590.0

# %%
total_points1617_lal = 0
for player in lakers_2016_17:
  player_points = lal_games_1617[lal_games_1617['player'] == player]['points'].sum()
  total_points1617_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1617_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 8620.0

# %%
total_points1718_lal = 0
for player in lakers_2017_18:
  player_points = lal_games_1718[lal_games_1718['player'] == player]['points'].sum()
  total_points1718_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1718_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 8878.0

# %%
total_points1819_lal = 0
for player in lakers_2018_19:
  player_points = lal_games_1819[lal_games_1819['player'] == player]['points'].sum()
  total_points1819_lal += player_points

print(f"Total points for LAL players in the 2013-2014 season: {total_points1819_lal}")
# Out:
# Total points for LAL players in the 2013-2014 season: 9061.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define Lakers colors
lakers_purple = "#552583"
lakers_gold = "#FDB927"

# Apply seaborn theme
sns.set_theme(style="whitegrid")

# Data
years = [
    '13-14', '14-15', '15-16', '16-17', '17-18', '18-19',
    '19-20', '20-21', '21-22', '22-23', '23-24'
]
total_scores = [
    total_points1314_lal, total_points1415_lal, total_points1516_lal,
    total_points1617_lal, total_points1718_lal, total_points1819_lal,
    total_points1920, total_points2021, total_points2122, total_points2223,
    total_points2324
]

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=years, y=total_scores, marker='o', color=lakers_purple, linewidth=2.5,
             markerfacecolor=lakers_gold, markeredgecolor='black')

# Add vertical line and annotation for AD joining
ad_index = years.index('19-20')
plt.axvline(x=ad_index, color=lakers_gold, linestyle='--', linewidth=2)
plt.text(ad_index + 0.1, max(total_scores) * 0.95, 'Anthony Davis joins', color=lakers_gold,
         fontsize=10, fontweight='bold')

# Customize the plot
plt.title("Total Score of Lakers (2013–2024)", fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel("Season", fontsize=12)
plt.ylabel("Total Points", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
data_1314.head()
# Out:
#     game_id                data_set        date             a1           a2  \
# 0  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 1  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 2  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 3  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
# 4  21300322  2013-14 Regular Season  2013-12-11  Spencer Hawes  Tony Wroten
#
#             a3               a4              a5              h1           h2  \
# 0  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 1  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 2  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 3  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
# 4  Evan Turner  Hollis Thompson  Thaddeus Young  Nikola Pekovic  Ricky Rubio
#
# ...

# %%
# Total possessions: one per unique offensive sequence (custom logic)
# Example: count 'turnover', 'made shot', 'missed shot rebounded by defense'

#1314
estimated_possessions1314 = lal_games_1314[
    (lal_games_1314['team'] == 'LAL') &
    (lal_games_1314['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1314 = total_points1314_lal / estimated_possessions1314 if estimated_possessions1314 > 0 else 0

#1415
estimated_possessions1415 = lal_games_1415[
    (lal_games_1415['team'] == 'LAL') &
    (lal_games_1415['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1415 = total_points1415_lal / estimated_possessions1415 if estimated_possessions1415 > 0 else 0

#1516
estimated_possessions1516 = lal_games_1516[
    (lal_games_1516['team'] == 'LAL') &
    (lal_games_1516['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1516 = total_points1516_lal / estimated_possessions1516 if estimated_possessions1516 > 0 else 0

#1617
estimated_possessions1617 = lal_games_1617[
    (lal_games_1617['team'] == 'LAL') &
    (lal_games_1617['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1617 = total_points1617_lal / estimated_possessions1617 if estimated_possessions1617 > 0 else 0

#1718
estimated_possessions1718 = lal_games_1718[
    (lal_games_1718['team'] == 'LAL') &
    (lal_games_1718['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1718 = total_points1718_lal / estimated_possessions1718 if estimated_possessions1718 > 0 else 0

#1819
estimated_possessions1819 = lal_games_1819[
    (lal_games_1819['team'] == 'LAL') &
    (lal_games_1819['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1819 = total_points1819_lal / estimated_possessions1819 if estimated_possessions1819 > 0 else 0

#1920
estimated_possessions1920 = lal_games_1920[
    (lal_games_1920['team'] == 'LAL') &
    (lal_games_1920['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_1920 = total_points1920 / estimated_possessions1920 if estimated_possessions1920 > 0 else 0

#2021
estimated_possessions2021 = lal_games_2021[
    (lal_games_2021['team'] == 'LAL') &
    (lal_games_2021['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_2021 = total_points2021 / estimated_possessions2021 if estimated_possessions2021 > 0 else 0

#2122
estimated_possessions2122 = lal_games_2122[
    (lal_games_2122['team'] == 'LAL') &
    (lal_games_2122['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_2122 = total_points2122 / estimated_possessions2122 if estimated_possessions2122 > 0 else 0

#2223
estimated_possessions2223 = lal_games_2223[
    (lal_games_2223['team'] == 'LAL') &
    (lal_games_2223['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_2223 = total_points2223 / estimated_possessions2223 if estimated_possessions2223 > 0 else 0

#2324
estimated_possessions2324 = lal_games_2324[
    (lal_games_2324['team'] == 'LAL') &
    (lal_games_2324['event_type'].isin(['shot', 'turnover']))
]['play_id'].nunique()
ppp_2324 = total_points2324 / estimated_possessions2324 if estimated_possessions2324 >0 else 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lakers colors
lakers_purple = "#552583"
lakers_gold = "#FDB927"
x
# Data
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
possession_values = [estimated_possessions1314,estimated_possessions1415,estimated_possessions1516,
                     estimated_possessions1617,estimated_possessions1718,estimated_possessions1819,
                     estimated_possessions1920,estimated_possessions2021,estimated_possessions2122,
                     estimated_possessions2223,estimated_possessions2324]

# Plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot PPP line
plt.plot(years, possession_values, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black')

# Add AD join marker (2019–20)
ad_index = years.index('2019-20')
plt.axvline(x=ad_index, color=lakers_gold, linestyle='--', linewidth=2)
plt.text(ad_index + 0.1, max(possession_values)*0.97, 'AD joins', color=lakers_gold,
         fontsize=10, fontweight='bold')

# Customize
plt.title('Lakers Estimated Possession Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('EP', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lakers colors
lakers_purple = "#552583"
lakers_gold = "#FDB927"

# Data
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
ppp_values = [ppp_1314, ppp_1415, ppp_1516, ppp_1617, ppp_1718, ppp_1819,
              ppp_1920, ppp_2021, ppp_2122, ppp_2223, ppp_2324]

# Plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot PPP line
plt.plot(years, ppp_values, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black')

# Add AD join marker (2019–20)
ad_index = years.index('2019-20')
plt.axvline(x=ad_index, color=lakers_gold, linestyle='--', linewidth=2)
plt.text(ad_index + 0.1, max(ppp_values)*0.97, 'AD joins', color=lakers_gold,
         fontsize=10, fontweight='bold')

# Customize
plt.title('Lakers Points Per Possession (PPP) Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('PPP', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.show()

# %%
davis_2021_analyze = lal_games_2021[lal_games_2021['assist'] == 'Anthony Davis'].count()
davis_2021_analyze
# Out:
# game_id             125
# data_set            125
# date                125
# a1                  125
# a2                  125
# a3                  125
# a4                  125
# a5                  125
# h1                  125
# h2                  125
# h3                  125
# h4                  125
# h5                  125
# period              125
# away_score          125
# home_score          125
# remaining_time      125
# elapsed             125
# play_length         125
# play_id             125
# team                125
# event_type          125
# assist              125
# away                  0
# home                  0
# block                 0
# entered               0
# left                  0
# num                   0
# opponent              0
# outof                 0
# player              125
# points              125
# possession            0
# reason                0
# result              125
# steal                 0
# type                125
# ...

# %%
lal_games_1314.head()
# Out:
#        game_id                data_set        date         a1           a2  \
# 6301  21300336  2013-14 Regular Season  2013-12-13  Pau Gasol  Kobe Bryant
# 6302  21300336  2013-14 Regular Season  2013-12-13  Pau Gasol  Kobe Bryant
# 6303  21300336  2013-14 Regular Season  2013-12-13  Pau Gasol  Kobe Bryant
# 6304  21300336  2013-14 Regular Season  2013-12-13  Pau Gasol  Kobe Bryant
# 6305  21300336  2013-14 Regular Season  2013-12-13  Pau Gasol  Kobe Bryant
#
#                a3           a4              a5           h1                h2  \
# 6301  Jordan Hill  Jodie Meeks  Wesley Johnson  Serge Ibaka  Kendrick Perkins
# 6302  Jordan Hill  Jodie Meeks  Wesley Johnson  Serge Ibaka  Kendrick Perkins
# 6303  Jordan Hill  Jodie Meeks  Wesley Johnson  Serge Ibaka  Kendrick Perkins
# 6304  Jordan Hill  Jodie Meeks  Wesley Johnson  Serge Ibaka  Kendrick Perkins
# 6305  Jordan Hill  Jodie Meeks  Wesley Johnson  Serge Ibaka  Kendrick Perkins
#
# ...

# %%
lal_games_1314['block'].value_counts()
# Out:
# block
# Pau Gasol            92
# Wesley Johnson       77
# Jordan Hill          64
# Robert Sacre         47
# Ryan Kelly           45
#                      ..
# Damian Lillard        1
# John Salmons          1
# Greivis Vasquez       1
# DeMarcus Cousins      1
# Marcus Morris Sr.     1
# Name: count, Length: 202, dtype: int64

# %%
total_blocks_1314 = 0  # Initialize total blocks for the season

# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1314:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1314[lal_games_1314['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1314 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2013-2014 season: {total_blocks_1314}")
# Out:
# Total blocks for Lakers players in the 2013-2014 season: 261

# %%
total_blocks_1415 = 0  # Initialize total blocks for the season

# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1415:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1415[lal_games_1415['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1415 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2013-2014 season: {total_blocks_1415}")
# Out:
# Total blocks for Lakers players in the 2013-2014 season: 214

# %%
total_blocks_1516 = 0  # Initialize total blocks for the season

# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1516:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1516[lal_games_1516['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1516 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2013-2014 season: {total_blocks_1516}")
# Out:
# Total blocks for Lakers players in the 2013-2014 season: 287

# %%
total_blocks_1617 = 0  # Initialize total blocks for the season

# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1617:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1617[lal_games_1617['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1617 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2016-2017 season: {total_blocks_1617}")
# Out:
# Total blocks for Lakers players in the 2016-2017 season: 230

# %%
lal_players_1718
# Out:
# ['LeBron James',
#  'Kyle Kuzma',
#  'Brandon Ingram',
#  'Julius Randle',
#  'Lonzo Ball',
#  'Kentavious Caldwell-Pope',
#  'Josh Hart',
#  'Brook Lopez',
#  'Javale McGee']

# %%
total_blocks_1718 = 0  # Initialize total blocks for the season



# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1718:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1718[lal_games_1718['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1718 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2013-2014 season: {total_blocks_1718}")
# Out:
# Total blocks for Lakers players in the 2013-2014 season: 298

# %%
total_blocks_1819 = 0  # Initialize total blocks for the season



# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_1819:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1819[lal_games_1819['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1819 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2018-2019 season: {total_blocks_1819}")
# Out:
# Total blocks for Lakers players in the 2018-2019 season: 346

# %%
total_blocks_1920 = 0  # Initialize total blocks for the season

lal_players_2019_2020

# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2019_2020:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1920[lal_games_1920['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1920 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2018-2019 season: {total_blocks_1920}")
# Out:
# Total blocks for Lakers players in the 2018-2019 season: 567

# %%
total_blocks_1920 = 0  # Initialize total blocks for the season


# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2019_2020:
    # Filter rows where the player performed a block
    player_blocks = lal_games_1920[lal_games_1920['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_1920 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2019-2020 season: {total_blocks_1920}")
# Out:
# Total blocks for Lakers players in the 2019-2020 season: 567

# %%
total_blocks_2021 = 0  # Initialize total blocks for the season


# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2020_2021:
    # Filter rows where the player performed a block
    player_blocks = lal_games_2021[lal_games_2021['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_2021 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2019-2020 season: {total_blocks_2021}")
# Out:
# Total blocks for Lakers players in the 2019-2020 season: 341

# %%
total_blocks_2122 = 0  # Initialize total blocks for the season


# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2021_2022:
    # Filter rows where the player performed a block
    player_blocks = lal_games_2122[lal_games_2122['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_2122 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2021-2022 season: {total_blocks_2122}")
# Out:
# Total blocks for Lakers players in the 2021-2022 season: 358

# %%
total_blocks_2223 = 0  # Initialize total blocks for the season


# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2022_2023:
    # Filter rows where the player performed a block
    player_blocks = lal_games_2223[lal_games_2223['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_2223 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2022-2023 season: {total_blocks_2223}")
# Out:
# Total blocks for Lakers players in the 2022-2023 season: 395

# %%
total_blocks_2324 = 0  # Initialize total blocks for the season


# Loop through the list of Lakers players for the 2013-2014 season
for player in lal_players_2023_2024:
    # Filter rows where the player performed a block
    player_blocks = lal_games_2324[lal_games_2324['block'].str.contains(player, na=False)]

    # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
    total_blocks_2324 += len(player_blocks)  # Add the number of blocks (rows) to the total

print(f"Total blocks for Lakers players in the 2023-2024 season: {total_blocks_2324}")
# Out:
# Total blocks for Lakers players in the 2023-2024 season: 349

# %%
# prompt: plot the chart show total blocks of laker by seasons

# Lakers colors
lakers_purple = "#552583"
lakers_gold = "#FDB927"

# Data for the plot
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
total_blocks = [total_blocks_1314/82, total_blocks_1415/82, total_blocks_1516/82,
                total_blocks_1617/82, total_blocks_1718/82, total_blocks_1819/82,
                total_blocks_1920/82, total_blocks_2021/82, total_blocks_2122/82,
                total_blocks_2223/82, total_blocks_2324/82]

# Create the plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Add AD join marker (2019–20)


# Plot the total blocks
plt.plot(years, total_blocks, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black')

# Customize the plot
plt.title('Average Blocks Per Game by Lakers Players Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('Total Blocks', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Example data for total blocks (since actual data is not available here)
# These values should be replaced with the actual total blocks calculated from your dataset

# Data for the plot
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
total_blocks = [total_blocks_1314/82, total_blocks_1415/82, total_blocks_1516/82,
                total_blocks_1617/82, total_blocks_1718/82, total_blocks_1819/82,
                total_blocks_1920/82, total_blocks_2021/82, total_blocks_2122/82,
                total_blocks_2223/82, total_blocks_2324/82]

# Create the plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot the total blocks
plt.plot(years, total_blocks, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black')

# Add vertical line for when Davis joined the Lakers (2019-20 season)
plt.axvline(x='2019-20', color=lakers_gold, linestyle='--', label="AD Joins Lakers")

# Customize the plot
plt.title('Average Blocks Per Game by Lakers Players Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('Average Blocks Per Game', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# prompt: total_blocks_2324 = 0  # Initialize total blocks for the season
# # Loop through the list of Lakers players for the 2013-2014 season
# for player in lal_players_2023_2024:
#     # Filter rows where the player performed a block
#     player_blocks = lal_games_2324[lal_games_2324['block'].str.contains(player, na=False)]
#     # Count how many times the player performed a block (i.e., the number of occurrences of that player in the 'block' column)
#     total_blocks_2324 += len(player_blocks)  # Add the number of blocks (rows) to the total
# print(f"Total blocks for Lakers players in the 2023-2024 season: {total_blocks_2324}")
# - simialr with this code, calculate how many times laker player steal , do for 2013 to 2024

def calculate_steals(df, players):
    total_steals = 0
    for player in players:
        player_steals = df[df['steal'].str.contains(player, na=False)]
        total_steals += len(player_steals)
    return total_steals

# Assuming you have the dataframes lal_games_XXXX and player lists lal_players_XXXX for each season
seasons = {
    2014: {'games': lal_games_1314, 'players': lal_players_1314},
    2015: {'games': lal_games_1415, 'players': lal_players_1415},
    2016: {'games': lal_games_1516, 'players': lal_players_1516},
    2017: {'games': lal_games_1617, 'players': lal_players_1617},
    2018: {'games': lal_games_1718, 'players': lal_players_1718},
    2019: {'games': lal_games_1819, 'players': lal_players_1819},
    2020: {'games': lal_games_1920, 'players': lal_players_2019_2020},
    2021: {'games': lal_games_2021, 'players': lal_players_2020_2021},
    2022: {'games': lal_games_2122, 'players': lal_players_2021_2022},
    2023: {'games': lal_games_2223, 'players': lal_players_2022_2023},
    2024: {'games': lal_games_2324, 'players': lal_players_2023_2024},
}

for year, data in seasons.items():
    total_steals = calculate_steals(data['games'], data['players'])
    print(f"Total steals for Lakers players in the 20{year-1}-{year} season: {total_steals}")
# Out:
# Total steals for Lakers players in the 202013-2014 season: 284
# Total steals for Lakers players in the 202014-2015 season: 309
# Total steals for Lakers players in the 202015-2016 season: 522
# Total steals for Lakers players in the 202016-2017 season: 525
# Total steals for Lakers players in the 202017-2018 season: 411
# Total steals for Lakers players in the 202018-2019 season: 511
# Total steals for Lakers players in the 202019-2020 season: 722
# Total steals for Lakers players in the 202020-2021 season: 475
# Total steals for Lakers players in the 202021-2022 season: 458
# Total steals for Lakers players in the 202022-2023 season: 458
# Total steals for Lakers players in the 202023-2024 season: 429

# %%
# Example data for total blocks (since actual data is not available here)
# These values should be replaced with the actual total blocks calculated from your dataset

# Data for the plot
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
total_blocks = [284/82, 309/82, 522/82,
                525/82, 411/82,
                511/82, 722/82, 475/82,
                458/82, 458/82,429/81]

# Create the plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot the total blocks
plt.plot(years, total_blocks, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black')

# Add vertical line for when Davis joined the Lakers (2019-20 season)
plt.axvline(x='2019-20', color=lakers_gold, linestyle='--', label="AD Joins Lakers")

# Customize the plot
plt.title('Average Steals Per Game by Lakers Players Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('Average Steals Per Game', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# prompt: plot a chart to show both average blocks and steals per game of laker

import matplotlib.pyplot as plt

# Lakers colors
lakers_purple = "#552583"
lakers_gold = "#FDB927"

# Sample data (replace with your actual data)
years = ['2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19',
         '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
avg_blocks = [total_blocks_1314/82, total_blocks_1415/82, total_blocks_1516/82,
                total_blocks_1617/82, total_blocks_1718/82, total_blocks_1819/82,
                total_blocks_1920/82, total_blocks_2021/82, total_blocks_2122/82,
                total_blocks_2223/82, total_blocks_2324/82]
avg_steals = [284/82, 309/82, 522/82,
                525/82, 411/82,
                511/82, 722/82, 475/82,
                458/82, 458/82,429/81]


# Create the plot
plt.figure(figsize=(12, 6))

# Plot average blocks
plt.plot(years, avg_blocks, marker='o', color=lakers_purple, linewidth=2.5,
         markerfacecolor=lakers_gold, markeredgecolor='black', label='Average Blocks')

# Plot average steals
plt.plot(years, avg_steals, marker='s', color=lakers_gold, linewidth=2.5,
         markerfacecolor=lakers_purple, markeredgecolor='black', label='Average Steals')

# Add vertical line for when Davis joined the Lakers (2019-20 season)
plt.axvline(x='2019-20', color='gray', linestyle='--', label="AD Joins Lakers")

# Customize the plot
plt.title('Average Blocks and Steals Per Game by Lakers Players Over Time', fontsize=14, fontweight='bold', color=lakers_purple)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('Average Per Game', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
nop_games_1819['Other Stars On Court'] = np.where(nop_games_1819['On Court Players'].str.contains("Rudy Gay |DeMarcus Cousins "), "Stars on court", "Stars off court" )

nop_games_1819['Posession'] = np.where(nop_games_1819['team'] == 'SAC', "SAC", "Opponent")

nop_games_1819['Game_Min'] =  sac_games_1314['period'].astype('str') + "-" + sac_games_1314['elapsed'].str.split(":", expand = True)[1]

temp = pd.pivot_table(data = sac_games_1314,
                      index = ['Game_Min', 'game_name', 'Thomas on court', 'Other Stars On Court'],
                      columns = 'Posession',
                      values = 'points',
                      aggfunc = np.sum).reset_index().fillna(0)

temp['plus_minus'] = temp['SAC'] - temp['Opponent']

temp2 = pd.pivot_table(data = temp,
                       index = 'Thomas on court',
                       columns = 'Other Stars On Court',
                       values = 'plus_minus',
                       aggfunc = np.mean).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-182-15ec6a2063ea> in <cell line: 0>()
#       3 nop_games_1819['Posession'] = np.where(nop_games_1819['team'] == 'SAC', "SAC", "Opponent")
#       4
# ----> 5 nop_games_1819['Game_Min'] =  sac_games_1314['period'].astype('str') + "-" + sac_games_1314['elapsed'].str.split(":", expand = True)[1]
#       6
#       7 temp = pd.pivot_table(data = sac_games_1314,
#
# NameError: name 'sac_games_1314' is not defined

# %%
sac_games_1314['Other Stars On Court'].unique()

# %%
# Round columns correctly
#temp2["Stars On Court"] = np.round(temp2["Stars On Court"], 2)
temp2["Stars off court"] = np.round(temp2["Stars off court"], 2)

temp2

# %%
# Change "Stars On court" to "Stars On court" to match the column name
# Change "Stars On court" to "Stars on court" to match the column name
